# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
diretorio_atual = os.getcwd()
df = pd.read_csv(f'{diretorio_atual}/DNOPEN24.csv', sep=';')
# Out:
# /tmp/ipykernel_31462/1902197279.py:2: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{diretorio_atual}/DNOPEN24.csv', sep=';')

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(y='PESO', data=df, color=".8", linecolor="#137", linewidth=.75)
# Out:
# <Axes: ylabel='PESO'>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
df['IDADEMAE'].plot.hist(bins = 15)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
df['PESO'].plot.hist(bins = 15)
# Out:
# <Axes: ylabel='Frequency'>

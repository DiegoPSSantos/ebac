# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
diretorio_atual = os.getcwd()
df = pd.read_csv(f'{diretorio_atual}/DNOPEN24.csv', sep=';', low_memory=False)

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
sns.boxplot(y='IDADEMAE', data=df, color=".5", linewidth=.75)
# Out:
# <Axes: ylabel='IDADEMAE'>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(y='PESO', data=df, color=".8", linecolor="#137", linewidth=.75)
# Out:
# <Axes: ylabel='PESO'>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
df['IDADEMAE'].plot.hist(bins = 15)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
df['PESO'].plot.hist(bins = 15)
# Out:
# <Axes: ylabel='Frequency'>
